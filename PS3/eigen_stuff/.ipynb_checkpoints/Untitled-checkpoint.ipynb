# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("eigen_basis_1.8_5.dat")

# %%
plt.plot(data[:,0],data[:,1],color = "red",label='ours')
r = np.linspace(0,10,100)
y = 2*r*np.exp(-r)
plt.plot(r,y,color = "black",label='actual')
plt.legend()
